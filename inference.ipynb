# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
checkpoint = "/home/tooba.sheikh/Courses/IHA-YOLO/IHA-YOLO Checkpoints/CoNSeP/weights/best.pt"

# %%
img_path = "/home/tooba.sheikh/Courses/ConsepDataset/dataset/val/images/test_1_2.jpg"

# %%
model = YOLO(checkpoint)

# %%
results = model.predict(img_path)
# Out:
# image 1/1 /home/tooba.sheikh/Courses/ConsepDataset/dataset/val/images/test_1_2.jpg: 640x640 31 Inflammatorys, 170 Spindles, 9.2ms
# Speed: 8.2ms preprocess, 9.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
predicted_img = results[0].plot() 

plt.imshow(predicted_img)
plt.axis('off') 
plt.show()
